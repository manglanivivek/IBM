# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Vivek Manglani**
# I want to be a Data Scientist and Analyst.

# %% [markdown]
# *I want to be a Data Scientist because I like to manage things and have great interest in Computer and Information Technologies and hence it seems to be a field I will love working with.*

# %% [markdown]
# ### Code below is about adding Multiplying 2 numbers i.e. 2 and 4

# %%
print(2*4)
# Out:
# 8

# %% [markdown]
# Places Worth Exploring:
# 1. New York
# 2. California
# 3. London
#
# |Place||Country|
# |-----||-------|
# |New York|USA|
# |California|USA|
# |London|England|
#
#
# ![pexels-poyee-tsang-12139674.jpg](attachment:f1506a4d-9b0b-46d4-80e1-557bb33602d2.jpg)
